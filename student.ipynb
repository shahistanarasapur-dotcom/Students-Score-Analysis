# %% [markdown]
# Student Score Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv("/content/Students Performance.csv")
df.head()
# Out:
#    Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0          65             86             67               78            2021
# 1          64             85             71               80            2019
# 2          76             77             77               84            2021
# 3          80             76             75               75            2021
# 4          63             91             62               90            2019

# %%
correlation_matrix = df[['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score']].corr()
print(correlation_matrix)
# Out:
#                  Math_Score  Reading_Score  Writing_Score  Placement_Score
# Math_Score         1.000000      -0.073645       0.130120         0.022948
# Reading_Score     -0.073645       1.000000      -0.005636         0.093149
# Writing_Score      0.130120      -0.005636       1.000000         0.010894
# Placement_Score    0.022948       0.093149       0.010894         1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Scores')
plt.show()

# %%
sns.scatterplot(x='Math_Score', y='Placement_Score', data=df)
plt.title('Math Score vs Placement Score')
plt.xlabel('Math Score')
plt.ylabel('Placement Score')
plt.show()

# %%
sns.scatterplot(x='Reading_Score', y='Placement_Score', data=df)
plt.title('Reading Score vs Placement Score')
plt.xlabel('Reading Score')
plt.ylabel('Placement Score')
plt.show()

# %%
sns.scatterplot(x='Writing_Score', y='Placement_Score', data=df)
plt.title('Writing Score vs Placement Score')
plt.xlabel('Writing Score')
plt.ylabel('Placement Score')
plt.show()

# %% [markdown]
# MATH SCORE VS PLACEMENT SCORE

# %%
X = df.iloc[:, [0, 3]].values

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'orange', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'yellow', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'magenta', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'purple', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'black', label = 'Centroids')
plt.title('Clusters of Students')
plt.xlabel('Math Score')
plt.ylabel('Placement Score')
plt.legend()
plt.show()

# %% [markdown]
# READING SCORE VS PLACEMENT SCORE

# %%
X = df.iloc[:, [1, 3]].values

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'orange', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'yellow', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'magenta', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'purple', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'black', label = 'Centroids')
plt.title('Clusters of Students')
plt.xlabel('Reading Score')
plt.ylabel('Placement Score')
plt.legend()
plt.show()

# %% [markdown]
# WRITING SCORE VS PLACEMENT SCORE

# %%
X = df.iloc[:, [2, 3]].values

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'orange', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'yellow', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'magenta', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'purple', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'black', label = 'Centroids')
plt.title('Clusters of Students')
plt.xlabel('Writing Score')
plt.ylabel('Placement Score')
plt.legend()
plt.show()

# %%
df['Total_Score'] = df[['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score']].sum(axis=1)

# %%
colors = ['green' if score > 360 else 'red' if score < 280 else 'blue' for score in df['Total_Score']]

plt.figure(figsize=(10, 10))
plt.scatter(df['Club_Join_Date'], df['Total_Score'], color=colors, alpha=1)
plt.title('Club Join Date vs Total Score')
plt.xlabel('Club Join Date')
plt.ylabel('Total Score')
plt.grid(True)
plt.show()
